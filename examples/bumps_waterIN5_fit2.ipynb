# %% [markdown]
# <a id='Table of Contents'></a><h3>Table of Contents</h3>
#
# - <a href='#introduction'>Introduction</a>
# - <a href='#imports'>Import and install required librairies</a>
# - <a href='#setting_fitting'>Setting of fitting</a>
# - <a href='#run_fit'>Running the fit</a>
# - <a href='#results'>Showing the results</a>

# %% [markdown]
# (<a href='#Table of Contents'>Top</a>)<a id='introduction'></a><h2>Introduction</h2>
#
# <div class="alert alert-block alert-info">
# The objective of this notebook is to show how to use the `water_teixeira` model .
# </div>
#
# The data are two sets of water data measured at IN5 (ILL) using two different wavelengths.
#
# **Reference:** J. Qvist, H. Schober and B. Halle, J. Chem. Phys. 134, 144508 (2011)

# %% [markdown]
# (<a href='#Table of Contents'>Top</a>)<a id='imports'></a><h2> Import python modules for plotting, fitting... </h2>

# %%
# Imported required libraries
from __future__ import print_function
import sys
import os

import ipywidgets

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# install bumps (if not already installed)
# !{sys.executable} -m pip install bumps
# Out:
# Requirement already satisfied: bumps in /Users/celinedurniak/anaconda/envs/aseenv/lib/python2.7/site-packages (0.7.6)
# Requirement already satisfied: six in /Users/celinedurniak/.local/lib/python2.7/site-packages (from bumps) (1.11.0)
# sasview 4.0 requires lxml, which is not installed.
# sasview 4.0 requires periodictable>=1.3.1, which is not installed.
# sasview 4.0 requires pillow, which is not installed.
# sasview 4.0 has requirement pyparsing<2.0.0, but you'll have pyparsing 2.2.0 which is incompatible.
# nglview 1.0 has requirement ipywidgets==7, but you'll have ipywidgets 7.0.3 which is incompatible.

# %% [markdown]
#  (<a href='#Table of Contents'>Top</a>)<a id='setting_fitting'></a><h2>Setting of fitting </h2>
# <h3> load data, prepare data, create fitting model and set initial guesses </h3>
#
# These settings are saved in a Python script, which will be used by Bumps to run the fit.

# %%
# Name of Python script containing the model
model_file = "model_fit_water2.py"

# %%
# %%writefile $model_file
# import h5py
# import QENSmodels
# import numpy as np
# from scipy.integrate import simps
# from bumps.names import *
#
# path_to_data = './data/'
#
# import h5py
# import QENSmodels
# import qens_models # to be removed
# import numpy as np
# from scipy.integrate import simps
# from bumps.names import *
#
# # Data
# # Wavelength 5 Angstrom
# f = h5py.File(path_to_data + 'H2O_293K_5A.hdf', 'r')
# hw_5A = f['entry1']['data1']['X'][:]
# q_5A = f['entry1']['data1']['Y'][:]
# sqw_5A = np.transpose(f['entry1']['data1']['DATA'][:])
# err_5A = np.transpose(f['entry1']['data1']['errors'][:])
# f.close()
#
# # Wavelength 8 Angstrom
# f = h5py.File(path_to_data + 'H2O_293K_8A.hdf', 'r')
# hw_8A = f['entry1']['data1']['X'][:]
# q_8A = f['entry1']['data1']['Y'][:]
# sqw_8A = np.transpose(f['entry1']['data1']['DATA'][:])
# err_8A = np.transpose(f['entry1']['data1']['errors'][:])
# f.close()
#
# # Resolution
# # Wavelength 5 Angstrom
# f = h5py.File(path_to_data + 'V_273K_5A.hdf', 'r')
# res_5A = np.transpose(f['entry1']['data1']['DATA'][:])
# f.close()
#
# # Wavelength 8 Angstrom
# f = h5py.File(path_to_data + 'V_273K_8A.hdf', 'r')
# res_8A = np.transpose(f['entry1']['data1']['DATA'][:])
# f.close()
#
# # Force resolution function to have unit area
# # 5 Angstrom
# for i in range(len(q_5A)):
#     area = simps(res_5A[:,i], hw_5A)
#     res_5A[:,i] /= area
#
# # 8 Angstrom
# for i in range(len(q_8A)):
#     area = simps(res_8A[:,i], hw_8A)
#     res_8A[:,i] /= area
#
# # Fit range -1 to +1 meV
# idx_5A = np.where(np.logical_and(hw_5A > -1.0, hw_5A < 1.0))
# idx_8A = np.where(np.logical_and(hw_8A > -1.0, hw_8A < 1.0))
#
# def model_convol(x, q, scale=1, center=0, D=1, resTime=1, radius=1, DR=1, resolution=None):
#     model = QENSmodels.sqwWaterTeixeira(x, q, scale, center, D, resTime, radius, DR)
#     return np.convolve(model, resolution/resolution.sum(), mode='same')
#
# # Fit
# M = []
#
# # First dataset: wavelength=5 Angstrom
# for i in range(len(q_5A)):
#
#     x = hw_5A[idx_5A]
#     data = sqw_5A[idx_5A, i]
#     error = err_5A[idx_5A, i]
#     resol = res_5A[idx_5A,i]
#
#     # Select only valid data (error = -1 for Q, w points not accessible)
#     valid = np.where(error > 0.0)
#     x = x[valid[1]]
#     data = data[valid]
#     error = error[valid]
#     resol = resol[valid]
#
#     # Teixeira model
#     Mq = Curve(model_convol, x, data, error, q=q_5A[i],
#                scale=10, center=0.0, D=0.13, resTime=0.1, radius=1.0,
#                DR=0.3, resolution=resol)
#
#     # Fitted parameters
#     Mq.scale.range(0, 1e2)
#     Mq.center.range(-0.1,0.1)
#     Mq.D.range(0.05, 0.25)
#     Mq.resTime.range(0,1)
#     Mq.radius.range(0.9,1.1)
#     Mq.DR.range(0,1)
#
#     # Q-independent parameters
#     if i == 0:
#         QD = Mq.D
#         QT = Mq.resTime
#         QR = Mq.radius
#         QDR = Mq.DR
#     else:
#         Mq.D = QD
#         Mq.resTime = QT
#         Mq.radius = QR
#         Mq.DR = QDR
#
#     M.append(Mq)
#
# # Second dataset: wavelength=8 Angstrom
# for i in range(len(q_8A)):
#
#     x = hw_8A[idx_8A]
#     data = sqw_8A[idx_8A, i]
#     error = err_8A[idx_8A, i]
#     resol = res_8A[idx_8A,i]
#
#     # Select only valid data (error = -1 for Q, w points not accessible)
#     valid = np.where(error > 0.0)
#     x = x[valid[1]]
#     data = data[valid]
#     error = error[valid]
#     resol = resol[valid]
#
#     Mq = Curve(model_convol, x, data, error, q=q_8A[i],
#                scale=10, center=0.0, D=0.13, resTime=0.1, radius=1.0,
#                DR=0.3, resolution=resol)
#
#     # Fitted parameters
#     Mq.scale.range(0, 1e2)
#     Mq.center.range(-0.1,0.1)
#     Mq.D.range(0.05, 0.25)
#     Mq.resTime.range(0,1)
#     Mq.radius.range(0.9,1.1)
#     Mq.DR.range(0,1)
#
#     # Q-independent parameters set with 5A data
#     Mq.D = QD
#     Mq.resTime = QT
#     Mq.radius = QR
#     Mq.DR = QDR
#
#     M.append(Mq)
#
# problem = FitProblem(M)
# Out:
# Overwriting model_fit_water2.py

# %% [markdown]
# <h3> Choice of minimizer for bumps </h3>

# %%
w_choice_minimizer = ipywidgets.widgets.Dropdown(
    options={'Levenberg-Marquardt': "lm", 
             'Nelder-Mead Simplex': "amoeba", 
             'DREAM': "dream", 
             'Differential Evolution': "de", 
             'Quasi-Newton BFGS': "newton", 
             'Random Lines (experimental)': "rl", 
             'Particle Swarm (experimental)': "ps", 
             'Parallel Tempering (experimental)': "pt"},
    value="lm",
    description='Minimizer:',)

display(w_choice_minimizer)
# Out:
# Dropdown(description=u'Minimizer:', index=4, options={'Quasi-Newton BFGS': 'newton', 'Random Lines (experimental)': 'rl', 'Parallel Tempering (experimental)': 'pt', 'Particle Swarm (experimental)': 'ps', 'Levenberg-Marquardt': 'lm', 'Differential Evolution': 'de', 'Nelder-Mead Simplex': 'amoeba', 'DREAM': 'dream'}, value='lm')

# %% [markdown]
# <h3> Setting for running bumps </h3>

# %%
# CHOICE OF MINIMIZER
minimiser = w_choice_minimizer.value

# NUMBER OF STEPS WHEN RUNNING THE FIT
steps = 100

# output folder to save thre results
output_folder = 'QENS'

# %% [markdown]
# (<a href='#Table of Contents'>Top</a>)<a id='running_fit'></a><h2>Running the fit</h2>
#
# Run the fit using the *minimizer* defined above with a number of *steps* also specified above
# The subfolder *output_folder* contains different results: plots and
# refined parameters

# %%
# %run -m bumps.cli $model_file --fit=$minimiser --steps=$steps --store=$output_folder
# Out:
# # /Users/celinedurniak/anaconda/envs/aseenv/lib/python2.7/site-packages/bumps/cli.py model_fit_water2.py --fit=lm --steps=100 --store=QENS
# -- Model 0
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(0.5, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=16926.675(98), nllf=609360]
# -- Model 1
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(0.6, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=8165.438(89), nllf=322535]
# -- Model 2
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(0.7, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=8409.463(89), nllf=332174]
# -- Model 3
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(0.8, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=9009.774(89), nllf=355886]
# -- Model 4
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(0.9, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=9403.648(89), nllf=371444]
# -- Model 5
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(1, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=9175.749(89), nllf=362442]
# -- Model 6
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(1.1, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=8739.120(89), nllf=345195]
# -- Model 7
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(1.2, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=8176.761(89), nllf=322982]
# -- Model 8
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(1.3, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=8015.314(89), nllf=316605]
# -- Model 9
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(1.4, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=7786.790(89), nllf=307578]
# -- Model 10
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(1.5, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=7863.461(89), nllf=310607]
# -- Model 11
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(1.6, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=8049.900(89), nllf=317971]
# -- Model 12
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(1.7, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=7863.189(89), nllf=310596]
# -- Model 13
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(1.8, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=7674.067(89), nllf=303126]
# -- Model 14
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(1.9, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=7886.996(89), nllf=311536]
# -- Model 15
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(2, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=8238.861(89), nllf=325435]
# -- Model 16
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(2.1, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=9032.204(89), nllf=356772]
# -- Model 17
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(0.3, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=9675.170(36), nllf=938491]
# -- Model 18
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(0.4, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=5075.640(20), nllf=911077]
# -- Model 19
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(0.5, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=3859.587(20), nllf=692796]
# -- Model 20
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(0.6, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=3452.398(20), nllf=619705]
# -- Model 21
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(0.7, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=3132.546(20), nllf=562292]
# -- Model 22
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(0.8, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=2991.513(20), nllf=536977]
# -- Model 23
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(0.9, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=2985.961(20), nllf=535980]
# -- Model 24
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(1, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=3018.971(20), nllf=541905]
# -- Model 25
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(1.1, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=3012.001(20), nllf=540654]
# -- Model 26
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(1.2, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=3381.422(20), nllf=581605]
# -- Model 27
# .D = Parameter(0.13, name='D', bounds=(0.05,0.25))
# .DR = Parameter(0.3, name='DR', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .q = Parameter(1.3, name='q')
# .radius = Parameter(1, name='radius', bounds=(0.9,1.1))
# .resTime = Parameter(0.1, name='resTime', bounds=(0,1))
# .scale = Parameter(10, name='scale', bounds=(0,100))
#
# [chisq=4702.078(24), nllf=686503]
# [overall chisq=5235.127(13), nllf=1.30302e+07]

# %% [markdown]
# (<a href='#Table of Contents'>Top</a>)<a id='results'></a><h2>Showing the results </h2>

# %%
# DISPLAY SOME RESULTS (Bumps output)
par_file = os.path.splitext(model_file)[0] + '.par'
err_file = os.path.splitext(model_file)[0] + '.err'

with open(os.path.join('.', output_folder, par_file), 'r') as fid:
    for line in fid:
        parameter, value = line.split()
        print(parameter, value)
        
with open(os.path.join(os.getcwd(), output_folder, err_file), 'r') as ferr:
    for line in ferr:
        print(line.rsplit('\n')[0])
# Out:
# A0 0
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 20
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 20
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 20
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 20
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 20
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 20
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 20
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 20
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 20
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 20
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 20
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 20
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 20
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 20
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 20
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 20
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 20
# A0 0
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 35
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 35
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 35
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 35
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 35
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 35
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 35
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 35
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 35
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 35
# A1 0.9
# center 0
# hwhm1 0.05
# hwhm2 0.3
# scale 35
# -- Model 0
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(0.5, name='q')
# .scale = Parameter(20, name='scale', bounds=(1e-12,20))
#
# [chisq=30178.308(98), nllf=1.08642e+06]
# -- Model 1
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(0.6, name='q')
# .scale = Parameter(20, name='scale', bounds=(1e-12,20))
#
# [chisq=78.467(89), nllf=3099.46]
# -- Model 2
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(0.7, name='q')
# .scale = Parameter(20, name='scale', bounds=(1e-12,20))
#
# [chisq=664.762(89), nllf=26258.1]
# -- Model 3
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(0.8, name='q')
# .scale = Parameter(20, name='scale', bounds=(1e-12,20))
#
# [chisq=2572.880(89), nllf=101629]
# -- Model 4
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(0.9, name='q')
# .scale = Parameter(20, name='scale', bounds=(1e-12,20))
#
# [chisq=5433.381(89), nllf=214619]
# -- Model 5
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(1, name='q')
# .scale = Parameter(20, name='scale', bounds=(1e-12,20))
#
# [chisq=9349.447(89), nllf=369303]
# -- Model 6
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(1.1, name='q')
# .scale = Parameter(20, name='scale', bounds=(1e-12,20))
#
# [chisq=14226.827(89), nllf=561960]
# -- Model 7
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(1.2, name='q')
# .scale = Parameter(20, name='scale', bounds=(1e-12,20))
#
# [chisq=20139.692(89), nllf=795518]
# -- Model 8
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(1.3, name='q')
# .scale = Parameter(20, name='scale', bounds=(1e-12,20))
#
# [chisq=26269.630(89), nllf=1.03765e+06]
# -- Model 9
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(1.4, name='q')
# .scale = Parameter(20, name='scale', bounds=(1e-12,20))
#
# [chisq=32019.377(89), nllf=1.26477e+06]
# -- Model 10
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(1.5, name='q')
# .scale = Parameter(20, name='scale', bounds=(1e-12,20))
#
# [chisq=38234.643(89), nllf=1.51027e+06]
# -- Model 11
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(1.6, name='q')
# .scale = Parameter(20, name='scale', bounds=(1e-12,20))
#
# [chisq=48244.791(89), nllf=1.90567e+06]
# -- Model 12
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(1.7, name='q')
# .scale = Parameter(20, name='scale', bounds=(1e-12,20))
#
# [chisq=64736.047(89), nllf=2.55707e+06]
# -- Model 13
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(1.8, name='q')
# .scale = Parameter(20, name='scale', bounds=(1e-12,20))
#
# [chisq=84562.611(89), nllf=3.34022e+06]
# -- Model 14
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(1.9, name='q')
# .scale = Parameter(20, name='scale', bounds=(1e-12,20))
#
# [chisq=109354.688(89), nllf=4.31951e+06]
# -- Model 15
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(2, name='q')
# .scale = Parameter(20, name='scale', bounds=(1e-12,20))
#
# [chisq=139244.903(89), nllf=5.50017e+06]
# -- Model 16
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(2.1, name='q')
# .scale = Parameter(20, name='scale', bounds=(1e-12,20))
#
# [chisq=163243.401(89), nllf=6.44811e+06]
# -- Model 17
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(0.3, name='q')
# .scale = Parameter(35, name='scale', bounds=(0.1,40))
#
# [chisq=23249.805(36), nllf=2.25523e+06]
# -- Model 18
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(0.4, name='q')
# .scale = Parameter(35, name='scale', bounds=(0.1,40))
#
# [chisq=13986.487(20), nllf=2.51057e+06]
# -- Model 19
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(0.5, name='q')
# .scale = Parameter(35, name='scale', bounds=(0.1,40))
#
# [chisq=9543.256(20), nllf=1.71301e+06]
# -- Model 20
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(0.6, name='q')
# .scale = Parameter(35, name='scale', bounds=(0.1,40))
#
# [chisq=7080.058(20), nllf=1.27087e+06]
# -- Model 21
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(0.7, name='q')
# .scale = Parameter(35, name='scale', bounds=(0.1,40))
#
# [chisq=5852.612(20), nllf=1.05054e+06]
# -- Model 22
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(0.8, name='q')
# .scale = Parameter(35, name='scale', bounds=(0.1,40))
#
# [chisq=5301.873(20), nllf=951686]
# -- Model 23
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(0.9, name='q')
# .scale = Parameter(35, name='scale', bounds=(0.1,40))
#
# [chisq=5059.398(20), nllf=908162]
# -- Model 24
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(1, name='q')
# .scale = Parameter(35, name='scale', bounds=(0.1,40))
#
# [chisq=5572.272(20), nllf=1.00022e+06]
# -- Model 25
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(1.1, name='q')
# .scale = Parameter(35, name='scale', bounds=(0.1,40))
#
# [chisq=6515.032(20), nllf=1.16945e+06]
# -- Model 26
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(1.2, name='q')
# .scale = Parameter(35, name='scale', bounds=(0.1,40))
#
# [chisq=10614.691(20), nllf=1.82573e+06]
# -- Model 27
# .A0 = Parameter(0, name='A0', bounds=(0,0.05))
# .A1 = Parameter(0.9, name='A1', bounds=(0,1))
# .center = Parameter(0, name='center', bounds=(-0.1,0.1))
# .hwhm1 = Parameter(0.05, name='hwhm1', bounds=(0,0.5))
# .hwhm2 = Parameter(0.3, name='hwhm2', bounds=(0,3))
# .q = Parameter(1.3, name='q')
# .scale = Parameter(35, name='scale', bounds=(0.1,40))
#
# [chisq=34709.040(24), nllf=5.06752e+06]
# [overall chisq=20737.440(31), nllf=5.07653e+07]
# /Users/celinedurniak/anaconda/envs/aseenv/lib/python2.7/site-packages/matplotlib/pyplot.py:3259: MatplotlibDeprecationWarning: The 'hold' keyword argument is deprecated since 2.0.
#   mplDeprecation)
# /Users/celinedurniak/anaconda/envs/aseenv/lib/python2.7/site-packages/matplotlib/pyplot.py:2562: MatplotlibDeprecationWarning: The 'hold' keyword argument is deprecated since 2.0.
#   mplDeprecation)
# /Users/celinedurniak/anaconda/envs/aseenv/lib/python2.7/site-packages/matplotlib/pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
# Plot the fitting results

from IPython.display import display, Image
relative_output_path = os.path.join('.', output_folder)
names = [f for f in os.listdir(relative_output_path) if f.endswith('.png')]

for name in names:
    display(Image(os.path.join(relative_output_path, name)))
